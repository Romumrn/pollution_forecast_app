# %%
# !pip install tensorflow

# %%
import pandas as pd

df = pd.read_csv("final_merged_data.csv",low_memory=False)

# %%
df
# Out:
#              id                      start                        end  CO  \
# 0       FR03088  2018-09-11T00:00:00+00:00  2018-09-11T01:00:00+00:00 NaN
# 1       FR03088  2018-09-11T00:00:00+00:00  2018-09-11T01:00:00+00:00 NaN
# 2       FR03088  2018-09-11T01:00:00+00:00  2018-09-11T02:00:00+00:00 NaN
# 3       FR03088  2018-09-11T01:00:00+00:00  2018-09-11T02:00:00+00:00 NaN
# 4       FR03088  2018-09-11T02:00:00+00:00  2018-09-11T03:00:00+00:00 NaN
# ...         ...                        ...                        ...  ..
# 802110  FR36032  2020-11-18T15:00:00+00:00  2020-11-18T16:00:00+00:00 NaN
# 802111  FR36032  2020-11-18T16:00:00+00:00  2020-11-18T17:00:00+00:00 NaN
# 802112  FR36032  2020-11-18T16:00:00+00:00  2020-11-18T17:00:00+00:00 NaN
# 802113  FR36032  2020-11-18T17:00:00+00:00  2020-11-18T18:00:00+00:00 NaN
# 802114  FR36032  2020-11-18T17:00:00+00:00  2020-11-18T18:00:00+00:00 NaN
#
#          NO2    O3  PM10  PM2.5  SO2           Climate_Name  ...   DXI2  \
# 0        NaN  73.3   NaN    NaN  NaN             CARPENTRAS  ...    NaN
# 1        NaN  73.3   NaN    NaN  NaN   PERNES LES FONTAINES  ...    NaN
# 2        NaN  73.7   NaN    NaN  NaN             CARPENTRAS  ...    NaN
# 3        NaN  73.7   NaN    NaN  NaN   PERNES LES FONTAINES  ...    NaN
# 4        NaN  64.8   NaN    NaN  NaN             CARPENTRAS  ...    NaN
# ...      ...   ...   ...    ...  ...                    ...  ...    ...
# 802110  49.6   NaN  13.0    2.0  NaN   ST-MARCEL-LES-V-INRA  ...  160.0
# 802111  52.9   NaN  21.6    4.3  NaN  ST-MARCEL-LES-V-INRAE  ...  160.0
# 802112  52.9   NaN  21.6    4.3  NaN   ST-MARCEL-LES-V-INRA  ...  160.0
# 802113  53.6   NaN  25.8   11.1  NaN  ST-MARCEL-LES-V-INRAE  ...  160.0
# 802114  53.6   NaN  25.8   11.1  NaN   ST-MARCEL-LES-V-INRA  ...  160.0
#
#         QDXI2    HXI2  QHXI2  FXI3S  QFXI3S  DXI3S  QDXI3S   HXI3S  QHXI3S
# 0         NaN     NaN    NaN    6.1     1.0    NaN     NaN  1547.0     9.0
# 1         NaN     NaN    NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 2         NaN     NaN    NaN    6.1     1.0    NaN     NaN  1547.0     9.0
# 3         NaN     NaN    NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 4         NaN     NaN    NaN    6.1     1.0    NaN     NaN  1547.0     9.0
# ...       ...     ...    ...    ...     ...    ...     ...     ...     ...
# 802110    9.0  1500.0    9.0    NaN     NaN    NaN     NaN     NaN     NaN
# 802111    9.0  1500.0    9.0    NaN     NaN    NaN     NaN     NaN     NaN
# 802112    9.0  1500.0    9.0    NaN     NaN    NaN     NaN     NaN     NaN
# 802113    9.0  1500.0    9.0    NaN     NaN    NaN     NaN     NaN     NaN
# 802114    9.0  1500.0    9.0    NaN     NaN    NaN     NaN     NaN     NaN
#
# [802115 rows x 153 columns]

# %%
data = df.dropna(axis=1, how='all')
data = data.drop( [ "Climate_Name" , "Climate_Latitude","Climate_Longitude", "Pollutant_Station_Code","NUM_POSTE", "end", "id","NOM_USUEL"],axis=1 )
data
# Out:
#                             start   NO2    O3  PM10  PM2.5  SO2  \
# 0       2018-09-11T00:00:00+00:00   NaN  73.3   NaN    NaN  NaN
# 1       2018-09-11T00:00:00+00:00   NaN  73.3   NaN    NaN  NaN
# 2       2018-09-11T01:00:00+00:00   NaN  73.7   NaN    NaN  NaN
# 3       2018-09-11T01:00:00+00:00   NaN  73.7   NaN    NaN  NaN
# 4       2018-09-11T02:00:00+00:00   NaN  64.8   NaN    NaN  NaN
# ...                           ...   ...   ...   ...    ...  ...
# 802110  2020-11-18T15:00:00+00:00  49.6   NaN  13.0    2.0  NaN
# 802111  2020-11-18T16:00:00+00:00  52.9   NaN  21.6    4.3  NaN
# 802112  2020-11-18T16:00:00+00:00  52.9   NaN  21.6    4.3  NaN
# 802113  2020-11-18T17:00:00+00:00  53.6   NaN  25.8   11.1  NaN
# 802114  2020-11-18T17:00:00+00:00  53.6   NaN  25.8   11.1  NaN
#
#         Pollutant_Station_Latitude  Pollutant_Station_Longitude  Distance_km  \
# 0                         44.06035                     5.067413     2.692297
# 1                         44.06035                     5.067413     9.250319
# 2                         44.06035                     5.067413     2.692297
# 3                         44.06035                     5.067413     9.250319
# 4                         44.06035                     5.067413     2.692297
# ...                            ...                          ...          ...
# 802110                    44.94920                     4.890133     4.729016
# 802111                    44.94920                     4.890133     4.729016
# 802112                    44.94920                     4.890133     4.729016
# 802113                    44.94920                     4.890133     4.729016
# 802114                    44.94920                     4.890133     4.729016
#
#             date  ...  QFXI2   DXI2  QDXI2    HXI2  QHXI2  FXI3S  QFXI3S  \
# 0       20180911  ...    NaN    NaN    NaN     NaN    NaN    6.1     1.0
# 1       20180911  ...    NaN    NaN    NaN     NaN    NaN    NaN     NaN
# 2       20180911  ...    NaN    NaN    NaN     NaN    NaN    6.1     1.0
# 3       20180911  ...    NaN    NaN    NaN     NaN    NaN    NaN     NaN
# 4       20180911  ...    NaN    NaN    NaN     NaN    NaN    6.1     1.0
# ...          ...  ...    ...    ...    ...     ...    ...    ...     ...
# 802110  20201118  ...    9.0  160.0    9.0  1500.0    9.0    NaN     NaN
# 802111  20201118  ...    9.0  160.0    9.0  1500.0    9.0    NaN     NaN
# 802112  20201118  ...    9.0  160.0    9.0  1500.0    9.0    NaN     NaN
# 802113  20201118  ...    9.0  160.0    9.0  1500.0    9.0    NaN     NaN
# 802114  20201118  ...    9.0  160.0    9.0  1500.0    9.0    NaN     NaN
#
#         QDXI3S   HXI3S  QHXI3S
# 0          NaN  1547.0     9.0
# 1          NaN     NaN     NaN
# 2          NaN  1547.0     9.0
# 3          NaN     NaN     NaN
# 4          NaN  1547.0     9.0
# ...        ...     ...     ...
# 802110     NaN     NaN     NaN
# 802111     NaN     NaN     NaN
# 802112     NaN     NaN     NaN
# 802113     NaN     NaN     NaN
# 802114     NaN     NaN     NaN
#
# [802115 rows x 137 columns]

# %%
import datetime

data['start'] = pd.to_datetime(df['start'])

# Feature Engineering
data['hour'] = data['start'].dt.hour
data['day'] = data['start'].dt.day
data['month'] = data['start'].dt.month
data['year'] = data['start'].dt.year

data = data.drop("start", axis=1)

# %%
data.to_csv("data_to_ML.csv") 
data
# Out:
#          NO2    O3  PM10  PM2.5  SO2  Pollutant_Station_Latitude  \
# 0        NaN  73.3   NaN    NaN  NaN                    44.06035
# 1        NaN  73.3   NaN    NaN  NaN                    44.06035
# 2        NaN  73.7   NaN    NaN  NaN                    44.06035
# 3        NaN  73.7   NaN    NaN  NaN                    44.06035
# 4        NaN  64.8   NaN    NaN  NaN                    44.06035
# ...      ...   ...   ...    ...  ...                         ...
# 802110  49.6   NaN  13.0    2.0  NaN                    44.94920
# 802111  52.9   NaN  21.6    4.3  NaN                    44.94920
# 802112  52.9   NaN  21.6    4.3  NaN                    44.94920
# 802113  53.6   NaN  25.8   11.1  NaN                    44.94920
# 802114  53.6   NaN  25.8   11.1  NaN                    44.94920
#
#         Pollutant_Station_Longitude  Distance_km      date   ALTI  ...  QHXI2  \
# 0                          5.067413     2.692297  20180911   98.0  ...    NaN
# 1                          5.067413     9.250319  20180911    NaN  ...    NaN
# 2                          5.067413     2.692297  20180911   98.0  ...    NaN
# 3                          5.067413     9.250319  20180911    NaN  ...    NaN
# 4                          5.067413     2.692297  20180911   98.0  ...    NaN
# ...                             ...          ...       ...    ...  ...    ...
# 802110                     4.890133     4.729016  20201118  190.0  ...    9.0
# 802111                     4.890133     4.729016  20201118  190.0  ...    9.0
# 802112                     4.890133     4.729016  20201118  190.0  ...    9.0
# 802113                     4.890133     4.729016  20201118  190.0  ...    9.0
# 802114                     4.890133     4.729016  20201118  190.0  ...    9.0
#
#         FXI3S  QFXI3S  QDXI3S   HXI3S  QHXI3S  hour  day  month  year
# 0         6.1     1.0     NaN  1547.0     9.0     0   11      9  2018
# 1         NaN     NaN     NaN     NaN     NaN     0   11      9  2018
# 2         6.1     1.0     NaN  1547.0     9.0     1   11      9  2018
# 3         NaN     NaN     NaN     NaN     NaN     1   11      9  2018
# 4         6.1     1.0     NaN  1547.0     9.0     2   11      9  2018
# ...       ...     ...     ...     ...     ...   ...  ...    ...   ...
# 802110    NaN     NaN     NaN     NaN     NaN    15   18     11  2020
# 802111    NaN     NaN     NaN     NaN     NaN    16   18     11  2020
# 802112    NaN     NaN     NaN     NaN     NaN    16   18     11  2020
# 802113    NaN     NaN     NaN     NaN     NaN    17   18     11  2020
# 802114    NaN     NaN     NaN     NaN     NaN    17   18     11  2020
#
# [802115 rows x 140 columns]

# %%
# calculate the mean of each column
# Select only numeric columns for filling NaN values
numeric_cols = data.select_dtypes(include=['number']).columns

# Fill NaN values with the mean of each numeric column
data[numeric_cols] = data[numeric_cols].fillna(data[numeric_cols].mean())

# %%
data
# Out:
#               NO2         O3       PM10      PM2.5       SO2  \
# 0       12.681287  73.300000  14.066772   8.236811  4.692078
# 1       12.681287  73.300000  14.066772   8.236811  4.692078
# 2       12.681287  73.700000  14.066772   8.236811  4.692078
# 3       12.681287  73.700000  14.066772   8.236811  4.692078
# 4       12.681287  64.800000  14.066772   8.236811  4.692078
# ...           ...        ...        ...        ...       ...
# 802110  49.600000  53.502007  13.000000   2.000000  4.692078
# 802111  52.900000  53.502007  21.600000   4.300000  4.692078
# 802112  52.900000  53.502007  21.600000   4.300000  4.692078
# 802113  53.600000  53.502007  25.800000  11.100000  4.692078
# 802114  53.600000  53.502007  25.800000  11.100000  4.692078
#
#         Pollutant_Station_Latitude  Pollutant_Station_Longitude  Distance_km  \
# 0                         44.06035                     5.067413     2.692297
# 1                         44.06035                     5.067413     9.250319
# 2                         44.06035                     5.067413     2.692297
# 3                         44.06035                     5.067413     9.250319
# 4                         44.06035                     5.067413     2.692297
# ...                            ...                          ...          ...
# 802110                    44.94920                     4.890133     4.729016
# 802111                    44.94920                     4.890133     4.729016
# 802112                    44.94920                     4.890133     4.729016
# 802113                    44.94920                     4.890133     4.729016
# 802114                    44.94920                     4.890133     4.729016
#
#             date        ALTI  ...  QHXI2     FXI3S    QFXI3S    QDXI3S  \
# 0       20180911   98.000000  ...    9.0  6.100000  1.000000  6.052632
# 1       20180911  697.348152  ...    9.0  9.294434  5.900231  6.052632
# 2       20180911   98.000000  ...    9.0  6.100000  1.000000  6.052632
# 3       20180911  697.348152  ...    9.0  9.294434  5.900231  6.052632
# 4       20180911   98.000000  ...    9.0  6.100000  1.000000  6.052632
# ...          ...         ...  ...    ...       ...       ...       ...
# 802110  20201118  190.000000  ...    9.0  9.294434  5.900231  6.052632
# 802111  20201118  190.000000  ...    9.0  9.294434  5.900231  6.052632
# 802112  20201118  190.000000  ...    9.0  9.294434  5.900231  6.052632
# 802113  20201118  190.000000  ...    9.0  9.294434  5.900231  6.052632
# 802114  20201118  190.000000  ...    9.0  9.294434  5.900231  6.052632
#
#               HXI3S    QHXI3S  hour  day  month  year
# 0       1547.000000  9.000000     0   11      9  2018
# 1       1294.972394  8.981829     0   11      9  2018
# 2       1547.000000  9.000000     1   11      9  2018
# 3       1294.972394  8.981829     1   11      9  2018
# 4       1547.000000  9.000000     2   11      9  2018
# ...             ...       ...   ...  ...    ...   ...
# 802110  1294.972394  8.981829    15   18     11  2020
# 802111  1294.972394  8.981829    16   18     11  2020
# 802112  1294.972394  8.981829    16   18     11  2020
# 802113  1294.972394  8.981829    17   18     11  2020
# 802114  1294.972394  8.981829    17   18     11  2020
#
# [802115 rows x 140 columns]

# %%
# Aggregate data by station and day

group = [ "Pollutant_Station_Latitude", "Pollutant_Station_Longitude","date"]

aggregated_data = data.groupby(group).mean().reset_index()

# %%
aggregated_data
# Out:
#        Pollutant_Station_Latitude  Pollutant_Station_Longitude      date  \
# 0                       44.054474                     4.697408  20180917
# 1                       44.054474                     4.697408  20180918
# 2                       44.054474                     4.697408  20180919
# 3                       44.054474                     4.697408  20180920
# 4                       44.054474                     4.697408  20180921
# ...                           ...                          ...       ...
# 10876                   46.316174                     4.839994  20201114
# 10877                   46.316174                     4.839994  20201115
# 10878                   46.316174                     4.839994  20201116
# 10879                   46.316174                     4.839994  20201117
# 10880                   46.316174                     4.839994  20201118
#
#              NO2         O3       PM10      PM2.5       SO2  Distance_km  \
# 0      12.681287  53.502007  11.975000   9.441667  4.692078     8.978006
# 1      12.681287  53.502007  15.048611  13.354167  4.692078     8.978006
# 2      12.681287  53.502007  13.790278   3.568924  4.692078     8.978006
# 3      12.681287  53.502007  14.805556   9.844444  4.692078     8.978006
# 4      12.681287  53.502007  13.554892   7.917913  4.692078     8.978006
# ...          ...        ...        ...        ...       ...          ...
# 10876  14.537500  34.029167  14.716667   8.236811  4.692078     6.501974
# 10877   7.608333  48.245833  12.895833   8.236811  4.692078     6.501974
# 10878  17.541667  49.608333  12.108333   8.236811  4.692078     6.501974
# 10879  24.685278  17.711944  14.953245   8.236811  4.692078     6.501974
# 10880  28.472222  14.416667  17.374086   8.236811  4.692078     6.501974
#
#         ALTI  ...  QHXI2      FXI3S    QFXI3S    QDXI3S        HXI3S  \
# 0       30.0  ...    9.0   9.294434  5.900231  6.052632  1294.972394
# 1       30.0  ...    9.0   9.294434  5.900231  6.052632  1294.972394
# 2       30.0  ...    9.0   9.294434  5.900231  6.052632  1294.972394
# 3       30.0  ...    9.0   9.294434  5.900231  6.052632  1294.972394
# 4       30.0  ...    9.0   9.294434  5.900231  6.052632  1294.972394
# ...      ...  ...    ...        ...       ...       ...          ...
# 10876  209.5  ...    9.0  10.297217  3.450115  6.052632  1357.486197
# 10877  209.5  ...    9.0  12.797217  3.450115  6.052632  1260.986197
# 10878  209.5  ...    9.0  11.297217  3.450115  6.052632   769.486197
# 10879  209.5  ...    9.0   6.397217  3.450115  6.052632  1670.986197
# 10880  209.5  ...    9.0   9.197217  3.450115  6.052632  1206.986197
#
#          QHXI3S  hour   day  month    year
# 0      8.981829  11.5  17.0    9.0  2018.0
# 1      8.981829  11.5  18.0    9.0  2018.0
# 2      8.981829  11.5  19.0    9.0  2018.0
# 3      8.981829   4.0  20.0    9.0  2018.0
# 4      8.981829  11.5  21.0    9.0  2018.0
# ...         ...   ...   ...    ...     ...
# 10876  8.990914  11.5  14.0   11.0  2020.0
# 10877  8.990914  11.5  15.0   11.0  2020.0
# 10878  8.990914  11.5  16.0   11.0  2020.0
# 10879  8.990914  11.5  17.0   11.0  2020.0
# 10880  8.990914   8.5  18.0   11.0  2020.0
#
# [10881 rows x 140 columns]

# %%
from sklearn.preprocessing import StandardScaler
# Normalize the data
scaler = StandardScaler()
# Drop the grouping columns to scale only the numeric columns
scaled_features = scaler.fit_transform(aggregated_data.drop(columns=group))
# Create a DataFrame with the scaled features
scaled_df = pd.DataFrame(scaled_features, columns=aggregated_data.drop(columns=group).columns)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# List of pollutants to include
pollutants = [ "NO2", "O3", "PM10", "PM2.5", "SO2"]

# Prepare sequences
def create_sequences(data, num_days=15, prediction_days=7):
    sequences = []
    targets = []
    for i in range(len(data) - num_days - prediction_days):
        seq = data.iloc[i:i + num_days][pollutants].values
        target = data.iloc[i + num_days:i + num_days + prediction_days][pollutants].values
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# Group by station and create sequences
sequences = []
targets = []
for station, group in aggregated_data.groupby(["Pollutant_Station_Latitude", "Pollutant_Station_Longitude"]):
    seq, targ = create_sequences(group)
    sequences.extend(seq)
    targets.extend(targ)

sequences = np.array(sequences)
targets = np.array(targets)

# Split data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(sequences, targets, test_size=0.2, random_state=42)

# Print shapes to verify the split
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (7842, 15, 5), y_train shape: (7842, 7, 5)
# X_test shape: (1961, 15, 5), y_test shape: (1961, 7, 5)

# %%
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

def show_mse_graph(y_pred, y_test, pollutants):
    # Define a custom color palette for synthwave style
    colors = ['#FF6EC7', '#7A5AEC', '#FFD166', '#FF8C42', '#8AFFA5', '#4F5D75']
    
    # Calculate errors (absolute differences)
    errors = np.abs(y_pred - y_test)
    
    # Calculate MSE for each pollutant
    mse = np.zeros(len(pollutants))
    for i in range(len(pollutants)):
        mse[i] = mean_squared_error(y_test[:, :, i], y_pred[:, :, i])
    
    # Plotting
    plt.figure(figsize=(10, 6))
    bars = plt.bar(pollutants, mse, color=colors, alpha=0.7, edgecolor='black', linewidth=1.5, capsize=7)
    plt.title('Mean Square Error (MSE) for Each Pollutant', fontsize=16, fontweight='bold')
    plt.xlabel('Pollutant', fontsize=14)
    plt.ylabel('MSE', fontsize=14)
    plt.xticks(rotation=45, fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Adding mean values on top of each bar
    for bar, m in zip(bars, mse):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.15, f'{m:.2f}', ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')
    
    plt.tight_layout()
    plt.show()

# %%
# Plot training history
def plot_training_history(history):
    # Plot training & validation loss values
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, LSTM


modelCNN = Sequential([
    Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(15, sequences.shape[2])),
    MaxPooling1D(pool_size=2),
    Conv1D(filters=128, kernel_size=2, activation='relu'),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(128*2, activation='relu'),
    Dense(128, activation='relu'),
    Dropout(0.1),
    Dense(targets.shape[1] * targets.shape[2], activation='linear'),
    tf.keras.layers.Reshape((7, targets.shape[2]))
])

# Compile the model
modelCNN.compile(optimizer='adam', loss='mse')
# Out:
# C:\Users\Administrateur\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
historyCNN = modelCNN.fit(X_train, y_train, epochs=60, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 198.4906 - val_loss: 68.8658
# Epoch 2/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 76.0293 - val_loss: 76.4416
# Epoch 3/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 72.7913 - val_loss: 85.4653
# Epoch 4/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 74.0399 - val_loss: 63.5125
# Epoch 5/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 66.4259 - val_loss: 60.3240
# Epoch 6/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 63.6643 - val_loss: 63.2760
# Epoch 7/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 62.6987 - val_loss: 59.9962
# Epoch 8/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 61.9540 - val_loss: 57.2430
# Epoch 9/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 61.0659 - val_loss: 68.6999
# Epoch 10/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 61.1825 - val_loss: 56.2723
# Epoch 11/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 55.4734 - val_loss: 58.5020
# Epoch 12/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 55.2159 - val_loss: 53.6538
# Epoch 13/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 52.1893 - val_loss: 58.0067
# Epoch 14/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 50.1741 - val_loss: 52.8481
# Epoch 15/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 49.0328 - val_loss: 52.6243
# Epoch 16/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 50.5375 - val_loss: 53.9160
# Epoch 17/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 51.7680 - val_loss: 51.0218
# Epoch 18/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 49.4564 - val_loss: 52.9689
# Epoch 19/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 45.7622 - val_loss: 51.6417
# Epoch 20/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 49.8300 - val_loss: 59.5299
# Epoch 21/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 48.1283 - val_loss: 49.7825
# Epoch 22/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 43.6155 - val_loss: 48.7141
# Epoch 23/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 41.8942 - val_loss: 49.6689
# Epoch 24/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 42.8887 - val_loss: 49.6246
# Epoch 25/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 41.5852 - val_loss: 50.8011
# Epoch 26/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 42.8087 - val_loss: 48.8615
# Epoch 27/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39.6687 - val_loss: 48.1634
# Epoch 28/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39.8273 - val_loss: 47.0501
# Epoch 29/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 39.1763 - val_loss: 48.7040
# Epoch 30/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37.5300 - val_loss: 48.4955
# Epoch 31/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37.5652 - val_loss: 46.3121
# Epoch 32/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37.1539 - val_loss: 46.4946
# Epoch 33/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37.4997 - val_loss: 54.3920
# Epoch 34/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 40.2265 - val_loss: 49.2778
# Epoch 35/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 40.5309 - val_loss: 46.7892
# Epoch 36/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36.9177 - val_loss: 51.4763
# Epoch 37/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 35.4292 - val_loss: 44.6306
# Epoch 38/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 32.2475 - val_loss: 45.3726
# Epoch 39/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33.8200 - val_loss: 46.1426
# Epoch 40/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 36.4901 - val_loss: 45.3826
# Epoch 41/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33.4705 - val_loss: 44.2941
# Epoch 42/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33.8062 - val_loss: 47.7563
# Epoch 43/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33.4459 - val_loss: 45.1105
# Epoch 44/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 32.9436 - val_loss: 51.4238
# Epoch 45/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31.7301 - val_loss: 46.8258
# Epoch 46/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30.3410 - val_loss: 44.6253
# Epoch 47/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30.5213 - val_loss: 45.0860
# Epoch 48/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 29.3215 - val_loss: 47.4580
# Epoch 49/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 31.3846 - val_loss: 46.4712
# Epoch 50/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.9802 - val_loss: 43.9161
# Epoch 51/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.4296 - val_loss: 44.0948
# Epoch 52/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.8146 - val_loss: 43.7062
# Epoch 53/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.2906 - val_loss: 46.2301
# Epoch 54/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.6339 - val_loss: 43.4861
# Epoch 55/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.3031 - val_loss: 44.4495
# Epoch 56/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.9753 - val_loss: 44.0316
# Epoch 57/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.1410 - val_loss: 44.4635
# Epoch 58/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.0238 - val_loss: 43.8943
# Epoch 59/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.5968 - val_loss: 44.1940
# Epoch 60/60
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25.4918 - val_loss: 45.4475

# %%
# Call the function to plot training history
plot_training_history(historyCNN)

# %%
y_predCNN = modelCNN.predict(X_test)
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
show_mse_graph( y_test, y_predCNN, pollutants)

# %%
modelRNN = Sequential([
    LSTM(64, activation='relu', input_shape=(15, sequences.shape[2]), return_sequences=True),
    LSTM(128, activation='relu', return_sequences=True),
    Flatten(),
    Dense(128*2, activation='relu'),
    Dense(128, activation='relu'),
    Dropout(0.1),
    Dense(targets.shape[1] * targets.shape[2], activation='linear'),
    tf.keras.layers.Reshape((7, targets.shape[2]))
])


modelRNN.summary()
modelRNN.compile(optimizer='adam', loss='mse')


# Train the model
historyRNN = modelRNN.fit(X_train, y_train, epochs=70, batch_size=32, validation_split=0.2)
# Out:
# C:\Users\Administrateur\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 15, 64)              │          17,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 15, 128)             │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 1920)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │         491,776 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 35)                  │           4,515 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_1 (Reshape)                  │ (None, 7, 5)                │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 645,923 (2.46 MB)
#  Trainable params: 645,923 (2.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 178.3942 - val_loss: 65.5302
# Epoch 2/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 75.5194 - val_loss: 76.6204
# Epoch 3/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 72.9680 - val_loss: 64.7242
# Epoch 4/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 64.9447 - val_loss: 62.6606
# Epoch 5/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 61.3481 - val_loss: 58.4119
# Epoch 6/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 60.1416 - val_loss: 59.5154
# Epoch 7/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 57.2434 - val_loss: 65.3343
# Epoch 8/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 57.0756 - val_loss: 65.5014
# Epoch 9/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 58.2740 - val_loss: 53.5167
# Epoch 10/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 53.3238 - val_loss: 59.6159
# Epoch 11/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 52.3162 - val_loss: 55.0492
# Epoch 12/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 49.7895 - val_loss: 59.1007
# Epoch 13/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 52.3934 - val_loss: 50.2311
# Epoch 14/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 46.6095 - val_loss: 50.9878
# Epoch 15/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 44.5416 - val_loss: 47.7407
# Epoch 16/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 41.7296 - val_loss: 45.5752
# Epoch 17/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 41.6080 - val_loss: 45.9519
# Epoch 18/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 40.7253 - val_loss: 43.9540
# Epoch 19/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 41.0221 - val_loss: 45.8410
# Epoch 20/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 41.1239 - val_loss: 46.1171
# Epoch 21/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 46.0394 - val_loss: 45.2900
# Epoch 22/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 39.4676 - val_loss: 43.6503
# Epoch 23/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 36.4910 - val_loss: 44.2581
# Epoch 24/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 34.9039 - val_loss: 54.2218
# Epoch 25/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 40.2717 - val_loss: 53.9493
# Epoch 26/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 34.5631 - val_loss: 41.1995
# Epoch 27/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 32.0063 - val_loss: 39.6610
# Epoch 28/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 30.5411 - val_loss: 42.7050
# Epoch 29/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 30.5194 - val_loss: 39.4613
# Epoch 30/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 28.3232 - val_loss: 40.0415
# Epoch 31/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 27.8757 - val_loss: 38.9208
# Epoch 32/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 27.5500 - val_loss: 38.9764
# Epoch 33/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 27.0871 - val_loss: 38.6461
# Epoch 34/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 27.8567 - val_loss: 38.9307
# Epoch 35/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 27.2177 - val_loss: 39.4975
# Epoch 36/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 24.4081 - val_loss: 39.3008
# Epoch 37/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 24.3921 - val_loss: 38.6700
# Epoch 38/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 26.3112 - val_loss: 40.4015
# Epoch 39/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 26.6272 - val_loss: 39.3894
# Epoch 40/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 23.8709 - val_loss: 36.6014
# Epoch 41/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 22.2490 - val_loss: 37.6158
# Epoch 42/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 21.9281 - val_loss: 37.3251
# Epoch 43/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 21.2712 - val_loss: 39.6975
# Epoch 44/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 26.9457 - val_loss: 38.3236
# Epoch 45/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 21.1880 - val_loss: 37.2478
# Epoch 46/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 20.7617 - val_loss: 38.5079
# Epoch 47/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 20.4087 - val_loss: 37.5752
# Epoch 48/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 19.6424 - val_loss: 38.2534
# Epoch 49/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 21.4768 - val_loss: 37.3942
# Epoch 50/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 20.6073 - val_loss: 37.6845
# Epoch 51/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 19.3325 - val_loss: 37.5286
# Epoch 52/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 19.1306 - val_loss: 37.5697
# Epoch 53/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 22.8133 - val_loss: 36.0428
# Epoch 54/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 18.3452 - val_loss: 39.6352
# Epoch 55/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 21.1346 - val_loss: 35.2621
# Epoch 56/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 17.3475 - val_loss: 36.8414
# Epoch 57/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 19.2389 - val_loss: 35.8289
# Epoch 58/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 17.3400 - val_loss: 35.9110
# Epoch 59/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 16.9138 - val_loss: 36.2228
# Epoch 60/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 17.8348 - val_loss: 36.2226
# Epoch 61/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 16.8460 - val_loss: 36.9408
# Epoch 62/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 18.2645 - val_loss: 35.2993
# Epoch 63/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 16.3417 - val_loss: 37.0462
# Epoch 64/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 17.6318 - val_loss: 36.2118
# Epoch 65/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 17.1311 - val_loss: 36.1492
# Epoch 66/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 16.5772 - val_loss: 38.0884
# Epoch 67/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 17.2069 - val_loss: 35.8170
# Epoch 68/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 15.2945 - val_loss: 37.3500
# Epoch 69/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 16.2725 - val_loss: 35.4044
# Epoch 70/70
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 15.4017 - val_loss: 35.2432

# %%
# Call the function to plot training history
plot_training_history(historyRNN)

# %%
y_predRNN = modelRNN.predict(X_test)

show_mse_graph( y_test, y_predRNN, pollutants)
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
